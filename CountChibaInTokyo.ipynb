# %% [markdown]
# <a href="https://colab.research.google.com/github/gojiteji/ChibaIsTokyo/blob/main/CountChibaInTokyo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 出典：国税庁法人番号公表サイト（国税庁）https://www.houjin-bangou.nta.go.jp/riyokiyaku/

# %%
import pandas as pd

file_path = '13_tokyo_all_20231228.csv'
data = pd.read_csv(file_path, header=None)
data.head()
# Out:
#    0              1   2   3           4           5                 6   7   \
# 0   1  1000011000005   1   1  2018-04-02  2015-10-05           国立国会図書館 NaN
# 1   2  1000012010003   1   1  2018-04-02  2015-10-05             内閣法制局 NaN
# 2   3  1000012010011   1   1  2018-04-02  2015-10-05         郵政民営化推進本部 NaN
# 3   4  1000012010028   1   1  2018-04-02  2015-10-05         国土強靱化推進本部 NaN
# 4   5  1000012010036   1   1  2018-04-02  2017-12-06  特定複合観光施設区域整備推進本部 NaN
#
#     8    9   ...  20   21          22  23  \
# 0  101  東京都  ... NaN  NaN  2015-10-05   1
# 1  101  東京都  ... NaN  NaN  2015-10-05   1
# 2  101  東京都  ... NaN  NaN  2015-10-05   1
# 3  101  東京都  ... NaN  NaN  2015-10-05   1
# 4  101  東京都  ... NaN  NaN  2017-12-06   1
#
#                                                   24     25  \
# 0                              National Diet Library  Tokyo
# 1                         Cabinet Legislation Bureau  Tokyo
# 2  Headquarters for the Promotion of Privatizatio...  Tokyo
# ...

# %%
column_preview = {column: data[column].head() for column in data.columns}
chiba_included = data[6].str.contains('千葉')
chiba_count = chiba_included.sum()

total_count = len(data)

chiba_percentage = (chiba_count / total_count) * 100
chiba_count, chiba_percentage
# Out:
# (363, 0.029273320070288225)

# %%
data[chiba_included][[9,6]]
# Out:
#            9                               6
# 2627     東京都                   千葉ブタジエン工業株式会社
# 3190     東京都                       株式会社東京千葉家
# 11952    東京都                     セカイエ千葉４株式会社
# 14961    東京都                      有限会社千葉通信建設
# 15621    東京都                   有限会社千葉労務管理事務所
# ...      ...                             ...
# 1226250  東京都  新産業別労働組合ジェイ・エイ・エム東京千葉昭和飛行機労働組合
# 1227991  東京都                      千葉開発興業株式会社
# 1237424  東京都                 千葉県食品流通センター株式会社
# 1237473  東京都                株式会社千葉国際カントリークラブ
# 1237516  東京都                    千葉大多喜ゴルフ株式会社
#
# [363 rows x 2 columns]
